# %% [markdown]
# <a href="https://colab.research.google.com/github/Aryaa6603/yoloV5_obstacle_dec/blob/main/yolov5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/ultralytics/yolov5.git
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 12575, done.
# remote: Counting objects: 100% (127/127), done.
# remote: Compressing objects: 100% (73/73), done.
# remote: Total 12575 (delta 76), reused 95 (delta 54), pack-reused 12448
# Receiving objects: 100% (12575/12575), 12.26 MiB | 21.46 MiB/s, done.
# Resolving deltas: 100% (8668/8668), done.

# %%
# %cd yolov5/
# Out:
# /content/yolov5

# %%
# !pip install -U -r requirements.txt
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 11.2 MB 8.6 MB/s
# ...
#      |████████████████████████████████| 60.9 MB 103 kB/s
# ...
#      |████████████████████████████████| 3.1 MB 49.5 MB/s
# ...
#      |████████████████████████████████| 596 kB 59.4 MB/s
# ...
#      |████████████████████████████████| 62 kB 1.4 MB/s
# ...
#      |████████████████████████████████| 750.6 MB 11 kB/s
# ...
#      |████████████████████████████████| 21.0 MB 40.9 MB/s
# ...
#      |████████████████████████████████| 407 kB 48.6 MB/s
# ...
#      |████████████████████████████████| 5.8 MB 21.6 MB/s
# ...
#      |████████████████████████████████| 793 kB 46.1 MB/s
# ...
#      |████████████████████████████████| 281 kB 57.4 MB/s
# ...
#      |████████████████████████████████| 944 kB 51.7 MB/s
# ...
#      |████████████████████████████████| 1.1 MB 44.7 MB/s
# ...
#      |████████████████████████████████| 381 kB 45.8 MB/s
# ...
#   Attempting uninstall: requests
# ...

# %%
# !python detect.py --source ./data/images/street.jpg --weights yolov5s.pt --conf 0.4
# Out:
# detect: weights=['yolov5s.pt'], source=./data/images/street.jpg, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.4, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 v6.1-295-gf8722b4 Python-3.7.13 torch-1.11.0+cu102 CPU
#
# Fusing layers...
# YOLOv5s summary: 213 layers, 7225885 parameters, 0 gradients
# image 1/1 /content/yolov5/data/images/street.jpg: 384x640 5 persons, 2 bicycles, 10 cars, 1 truck, 1 dog, 1 handbag, Done. (0.247s)
# Speed: 3.6ms pre-process, 246.5ms inference, 1.5ms NMS per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/exp5

# %%
import cv2
import matplotlib.pyplot as plt
# %matplotlib inline

image = cv2.imread("/content/yolov5/runs/detect/exp5/street.jpg")
height, width = image.shape[:2]
resized_image = cv2.resize(image,(3*width, 3*height), interpolation = cv2.INTER_CUBIC)

fig = plt.gcf()
fig.set_size_inches(18, 10)
plt.axis("off")
plt.imshow(cv2.cvtColor(resized_image, cv2.COLOR_BGR2RGB))
plt.show()

# %%
# !python detect.py --source data/videos/street.mp4 --weights yolov5s.pt --conf 0.4
# Out:
# detect: weights=['yolov5s.pt'], source=data/videos/street.mp4, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.4, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 v6.1-295-gf8722b4 Python-3.7.13 torch-1.11.0+cu102 CPU
#
# Fusing layers...
# YOLOv5s summary: 213 layers, 7225885 parameters, 0 gradients
# video 1/1 (1/330) /content/yolov5/data/videos/street.mp4: 384x640 3 persons, 1 bench, 3 potted plants, Done. (0.274s)
# video 1/1 (2/330) /content/yolov5/data/videos/street.mp4: 384x640 4 persons, 1 bench, 3 potted plants, Done. (0.256s)
# video 1/1 (3/330) /content/yolov5/data/videos/street.mp4: 384x640 4 persons, 1 bench, 3 potted plants, Done. (0.240s)
# ...
